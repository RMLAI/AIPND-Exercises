# %% [markdown]
# <a href="https://colab.research.google.com/github/RMLAI/AIPND-Exercises/blob/master/Visualization_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# changing the working directory
cd drive/My Drive/Data
# Out:
# /content/drive/My Drive/Data

# %%
#checking the contents of the folder
# !ls
# Out:
# Advertising.csv  covid_19_india.csv  Hitters_X_test.csv   Khan_ytrain.csv
# Auto.csv	 Credit.csv	     Hitters_X_train.csv  NCI60_X.csv
# Boston.csv	 Default.xlsx	     Hitters_y_test.csv   NCI60_y.csv
# Caravan.csv	 dog-photo.png	     Hitters_y_train.csv  panda.png
# car-photo.png	 Heart.csv	     Khan_xtest.csv	  Smarket.csv
# car-sales.csv	 heart-disease.csv   Khan_xtrain.csv	  USArrests.csv
# Carseats.csv	 Hitters.csv	     Khan_ytest.csv	  Wage.csv

# %%
#reading data from csv file
df=pd.read_csv('covid_19_india.csv')

# %%
#checking the dataframe
df.head()
# Out:
#    Sno      Date     Time  ... Cured Deaths Confirmed
# 0    1  30/01/20  6:00 PM  ...     0      0         1
# 1    2  31/01/20  6:00 PM  ...     0      0         1
# 2    3  01/02/20  6:00 PM  ...     0      0         2
# 3    4  02/02/20  6:00 PM  ...     0      0         3
# 4    5  03/02/20  6:00 PM  ...     0      0         3
#
# [5 rows x 9 columns]

# %%
# creating subset with only latest data
df1=df[df["Date"]=='30/03/20']

# %%
df1.head()
# Out:
#      Sno      Date      Time  ... Cured Deaths Confirmed
# 473  474  30/03/20  10:30 AM  ...     1      0        19
# 474  475  30/03/20  10:30 AM  ...     0      0         9
# 475  476  30/03/20  10:30 AM  ...     0      1        11
# 476  477  30/03/20  10:30 AM  ...     0      0         8
# 477  478  30/03/20  10:30 AM  ...     0      0         7
#
# [5 rows x 9 columns]

# %%
df1
# Out:
#      Sno      Date      Time  ... Cured Deaths Confirmed
# 473  474  30/03/20  10:30 AM  ...     1      0        19
# 474  475  30/03/20  10:30 AM  ...     0      0         9
# 475  476  30/03/20  10:30 AM  ...     0      1        11
# 476  477  30/03/20  10:30 AM  ...     0      0         8
# 477  478  30/03/20  10:30 AM  ...     0      0         7
# 478  479  30/03/20  10:30 AM  ...     6      2        53
# 479  480  30/03/20  10:30 AM  ...     0      0         5
# 480  481  30/03/20  10:30 AM  ...     1      5        58
# 481  482  30/03/20  10:30 AM  ...    17      0        33
# 482  483  30/03/20  10:30 AM  ...     0      1         3
# 483  484  30/03/20  10:30 AM  ...     1      2        31
# 484  485  30/03/20  10:30 AM  ...     5      3        80
# 485  486  30/03/20  10:30 AM  ...    19      1       194
# 486  487  30/03/20  10:30 AM  ...     3      0        13
# 487  488  30/03/20  10:30 AM  ...     0      2        33
# ...

# %%
df1.describe()
# Out:
#               Sno      Cured     Deaths   Confirmed
# count   27.000000  27.000000  27.000000   27.000000
# mean   487.000000   3.703704   1.074074   39.666667
# std      7.937254   6.591456   1.817139   50.761130
# min    474.000000   0.000000   0.000000    1.000000
# 25%    480.500000   0.000000   0.000000    7.000000
# 50%    487.000000   1.000000   0.000000   19.000000
# 75%    493.500000   3.500000   1.000000   55.000000
# max    500.000000  25.000000   8.000000  194.000000

# %%
import plotly.graph_objects as go

x = ['Product A', 'Product B', 'Product C']
y = [20, 14, 23]

# Use textposition='auto' for direct text
fig = go.Figure(data=[go.Bar(
            x=x, y=y,
            text=y,
            textposition='auto',
        )])

fig.show()

# %%
import plotly.graph_objects as go
x=df1['State/UnionTerritory']
y=df1['Confirmed']
# Use textposition='auto' for direct text
fig = go.Figure(data=[go.Bar(
            x=x, y=y,
            text=y,
            textposition='auto',
        )])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9c64e132-28fb-43bc-98ca-f4e37d0f3e6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9c64e132-28fb-43bc-98ca-f4e37d0f3e6b")) {
#                     Plotly.newPlot(
#                         '9c64e132-28fb-43bc-98ca-f4e37d0f3e6b',
# ...
